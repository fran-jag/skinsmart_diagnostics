# %%
#Check image paths

import os
import glob
import pathlib

images_dir = pathlib.Path('/home/papafrita/Projects/HAM10k_data/images') #Images are split in benign / malignant
contour_dir = pathlib.Path('/home/papafrita/Projects/HAM10k_data/segmentation_images')

images_list = list(images_dir.glob('*/*.jpg'))
contour_images_list = list(contour_dir.glob('*.png'))

print('Total images: {}'.format(len(images_list)))
print('Total contours: {}'.format(len(contour_images_list)))
# Out:
# Total images: 10015
# Total contours: 10015

# %%
import matplotlib
import PIL

contour = PIL.Image.open(contour_images_list[1])
contour
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=600x450>

# %%
contour.close()

# %%
contour.size
# Out:
# (600, 450)
